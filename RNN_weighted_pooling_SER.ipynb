# %%
import tensorflow as tf
from kapre.time_frequency import Melspectrogram,Spectrogram
from kapre.utils import Normalization2D
from tensorflow.keras import backend as K
from google.colab import drive
import os
import numpy as np
import librosa.display
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import IPython.display as ipd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Data Reading

# %%
def get_train_val_split(X_filepath, y_filepath, train_perc = 75, val_perc = 10):
    
    with open(X_filepath, 'rb') as load_file:
        data_X = np.load(load_file)
    with open(y_filepath, 'rb') as load_file:
        data_y = np.load(load_file)
    
    def standardize(X):
        return (X - X.mean()) / (X.std() + 0.000001)
    data_X = standardize(data_X)
    
    test_perc = 100 - (train_perc + val_perc)
    train_val_X, test_X, train_val_y, test_y = train_test_split(data_X, data_y, 
                                                                test_size = test_perc / 100, stratify = np.argmax(data_y, axis = 1), random_state = 42)
    train_X, val_X, train_y, val_y = train_test_split(train_val_X, train_val_y, 
                                                      test_size = val_perc / (train_perc + val_perc), stratify = np.argmax(train_val_y, axis = 1),random_state = 42)
    return train_X, train_y, val_X, val_y, test_X, test_y


EMOTIONS = ['Neutral', 'Calm', 'Happy', 'Sad', 'Angry', 'Fearful', 'Disgust', 'Surprised']

X_filepath = '/content/drive/MyDrive/8th sem/audio_project/dataset/Processed_Data/data_X.npy'
y_filepath = '/content/drive/MyDrive/8th sem/audio_project/dataset/Processed_Data/data_y.npy'

train_x,train_y,val_x,val_y,test_x,test_y = get_train_val_split(X_filepath,y_filepath)
train_x = np.expand_dims(train_x,axis=3)
test_x = np.expand_dims(test_x,axis=3)
val_x = np.expand_dims(val_x,axis=3)
print(train_x.shape)
print(train_y.shape)
print(val_x.shape)
print(val_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (1080, 228, 128, 1)
# (1080, 8)
# (144, 228, 128, 1)
# (144, 8)
# (216, 228, 128, 1)
# (216, 8)

# %% [markdown]
# #RNN model with weighted attention unit

# %%
def RNNSpeechModel(no_of_classes, input_size):
  
  # x = tf.keras.layers.Input((input_len,))
  # x = tf.keras.layers.Reshape((1,-1))(x)
  # m = Melspectrogram(n_dft=1024, n_hop=128, input_shape=(1, input_len),
  #                      padding='same', sr=sr, n_mels=80,
  #                      fmin=40.0, fmax=sr / 2, power_melgram=1.0,
  #                      return_decibel_melgram=True, trainable_fb=False,
  #                      trainable_kernel=False,
  #                      name='mel_stft')
  # m.trainable = False
  # x = m(x)
  #x = Normalization2D(int_axis=0)(x)
  #x = tf.keras.layers.Permute((2,1,3))(x)

  input = tf.keras.layers.Input((input_size))
  #Bidirectional RNN
  x = tf.keras.layers.Conv2D(10,(5,1),activation='relu',padding = 'same')(input)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(1,(5,1),activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Lambda(lambda q: K.squeeze(q, -1))(x)
  x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences = 'true'))(x)
  x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences = 'true'))(x)

  #Attention unit
  xFirst = tf.keras.layers.Lambda(lambda q: q[:,-1])(x)
  query = tf.keras.layers.Dense(128)(xFirst)
  att_score = tf.keras.layers.Dot(axes=[1,2])([query,x])
  att_score = tf.keras.layers.Softmax()(att_score)

  #weighted pooling
  att_vector = tf.keras.layers.Dot(axes=[1,1])([att_score,x])
  x = tf.keras.layers.Dense(64,activation='relu')(att_vector)
  x = tf.keras.layers.Dense(32,activation='relu')(x)
  output = tf.keras.layers.Dense(8,activation='softmax')(x)

  model = tf.keras.models.Model(inputs = input,outputs = output)
  return model
  
no_of_classes = 8
input_size = train_x[0].shape
model_speech = RNNSpeechModel(no_of_classes,input_size)
model_speech.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['acc'])
model_speech.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 228, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 228, 128, 10) 60          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 228, 128, 10) 40          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 228, 128, 1)  51          batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 228, 128, 1)  4           conv2d_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 228, 128)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 228, 128)     98816       lambda[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 228, 128)     98816       bidirectional[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16512       lambda_1[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 228)          0           dense[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# softmax (Softmax)               (None, 228)          0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 128)          0           softmax[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dot_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 8)            264         dense_2[0][0]
# ==================================================================================================
# Total params: 224,899
# Trainable params: 224,877
# Non-trainable params: 22
# __________________________________________________________________________________________________

# %% [markdown]
# #Training

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss' ,
                                                  factor = 0.5 , patience = 5 , verbose=1 , cooldown = 1,
                                                 min_delta = 0.000001)

checkpoint_filepath = '/content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    verbose = 1,
    save_best_only=True)

history = model_speech.fit(x = train_x, y=train_y, batch_size=32, 
                           validation_data=(val_x,val_y), steps_per_epoch = len(train_x)//32,
                           validation_steps=len(val_x)//32,
                           epochs = 100,callbacks = [reduce_lr,model_checkpoint_callback])

# history = model_speech.fit_generator(train_generator , validation_data = validation_generator , 
#                                   steps_per_epoch= len(train_generator) ,
#                                   validation_steps = len(validation_generator)
#                                   ,epochs = 100,callbacks = [reduce_lr,model_checkpoint_callback] )
# Out:
# Epoch 1/100
# 33/33 [==============================] - 40s 94ms/step - loss: 2.0806 - acc: 0.1446 - val_loss: 2.0620 - val_acc: 0.1406
#
# Epoch 00001: val_acc improved from -inf to 0.14062, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 2/100
# 33/33 [==============================] - 2s 48ms/step - loss: 1.8992 - acc: 0.2581 - val_loss: 2.0960 - val_acc: 0.1406
#
# Epoch 00002: val_acc did not improve from 0.14062
# Epoch 3/100
# 33/33 [==============================] - 2s 48ms/step - loss: 1.6197 - acc: 0.4249 - val_loss: 2.2785 - val_acc: 0.1406
#
# Epoch 00003: val_acc did not improve from 0.14062
# Epoch 4/100
# 33/33 [==============================] - 2s 48ms/step - loss: 1.4655 - acc: 0.4575 - val_loss: 2.4467 - val_acc: 0.1406
#
# Epoch 00004: val_acc did not improve from 0.14062
# Epoch 5/100
# 33/33 [==============================] - 2s 48ms/step - loss: 1.2433 - acc: 0.5526 - val_loss: 2.7774 - val_acc: 0.1406
#
# Epoch 00005: val_acc did not improve from 0.14062
# Epoch 6/100
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1860 - acc: 0.5597 - val_loss: 2.4201 - val_acc: 0.1875
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_acc improved from 0.14062 to 0.18750, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 7/100
# 33/33 [==============================] - 2s 47ms/step - loss: 1.0414 - acc: 0.6249 - val_loss: 2.6593 - val_acc: 0.1641
#
# Epoch 00007: val_acc did not improve from 0.18750
# Epoch 8/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.8209 - acc: 0.7097 - val_loss: 2.4347 - val_acc: 0.2500
#
# Epoch 00008: val_acc improved from 0.18750 to 0.25000, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 9/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.6967 - acc: 0.7483 - val_loss: 2.3520 - val_acc: 0.3125
#
# Epoch 00009: val_acc improved from 0.25000 to 0.31250, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 10/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.6100 - acc: 0.7839 - val_loss: 2.3636 - val_acc: 0.2500
#
# Epoch 00010: val_acc did not improve from 0.31250
# Epoch 11/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.5637 - acc: 0.8114 - val_loss: 2.7884 - val_acc: 0.2656
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_acc did not improve from 0.31250
# Epoch 12/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.4202 - acc: 0.8549 - val_loss: 2.3495 - val_acc: 0.3047
#
# Epoch 00012: val_acc did not improve from 0.31250
# Epoch 13/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.3583 - acc: 0.8865 - val_loss: 2.4418 - val_acc: 0.3516
#
# Epoch 00013: val_acc improved from 0.31250 to 0.35156, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 14/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.2869 - acc: 0.9030 - val_loss: 2.1040 - val_acc: 0.4219
#
# Epoch 00014: val_acc improved from 0.35156 to 0.42188, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 15/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.2050 - acc: 0.9516 - val_loss: 2.1408 - val_acc: 0.4141
#
# Epoch 00015: val_acc did not improve from 0.42188
# Epoch 16/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.1974 - acc: 0.9585 - val_loss: 1.8308 - val_acc: 0.5078
#
# Epoch 00016: val_acc improved from 0.42188 to 0.50781, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 17/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.1363 - acc: 0.9776 - val_loss: 1.6609 - val_acc: 0.5547
#
# Epoch 00017: val_acc improved from 0.50781 to 0.55469, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 18/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.1206 - acc: 0.9779 - val_loss: 1.6617 - val_acc: 0.5781
#
# Epoch 00018: val_acc improved from 0.55469 to 0.57812, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 19/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.1013 - acc: 0.9866 - val_loss: 1.6480 - val_acc: 0.5703
#
# Epoch 00019: val_acc did not improve from 0.57812
# Epoch 20/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0774 - acc: 0.9884 - val_loss: 1.4210 - val_acc: 0.5703
#
# Epoch 00020: val_acc did not improve from 0.57812
# Epoch 21/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0677 - acc: 0.9896 - val_loss: 1.5114 - val_acc: 0.6094
#
# Epoch 00021: val_acc improved from 0.57812 to 0.60938, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 22/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0526 - acc: 0.9979 - val_loss: 1.4703 - val_acc: 0.6328
#
# Epoch 00022: val_acc improved from 0.60938 to 0.63281, saving model to /content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5
# Epoch 23/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0492 - acc: 0.9979 - val_loss: 1.5296 - val_acc: 0.6094
#
# Epoch 00023: val_acc did not improve from 0.63281
# Epoch 24/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0332 - acc: 1.0000 - val_loss: 1.6021 - val_acc: 0.6250
#
# Epoch 00024: val_acc did not improve from 0.63281
# Epoch 25/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0326 - acc: 0.9979 - val_loss: 1.5545 - val_acc: 0.5781
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_acc did not improve from 0.63281
# Epoch 26/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0219 - acc: 0.9990 - val_loss: 1.5022 - val_acc: 0.6016
#
# Epoch 00026: val_acc did not improve from 0.63281
# Epoch 27/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0188 - acc: 1.0000 - val_loss: 1.5209 - val_acc: 0.6016
#
# Epoch 00027: val_acc did not improve from 0.63281
# Epoch 28/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0177 - acc: 0.9994 - val_loss: 1.5089 - val_acc: 0.6094
#
# Epoch 00028: val_acc did not improve from 0.63281
# Epoch 29/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0168 - acc: 1.0000 - val_loss: 1.5038 - val_acc: 0.6172
#
# Epoch 00029: val_acc did not improve from 0.63281
# Epoch 30/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0152 - acc: 1.0000 - val_loss: 1.5613 - val_acc: 0.6016
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00030: val_acc did not improve from 0.63281
# Epoch 31/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0136 - acc: 1.0000 - val_loss: 1.5217 - val_acc: 0.6172
#
# Epoch 00031: val_acc did not improve from 0.63281
# Epoch 32/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0130 - acc: 1.0000 - val_loss: 1.5202 - val_acc: 0.6094
#
# Epoch 00032: val_acc did not improve from 0.63281
# Epoch 33/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0142 - acc: 1.0000 - val_loss: 1.5284 - val_acc: 0.6094
#
# Epoch 00033: val_acc did not improve from 0.63281
# Epoch 34/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0135 - acc: 1.0000 - val_loss: 1.5225 - val_acc: 0.6172
#
# Epoch 00034: val_acc did not improve from 0.63281
# Epoch 35/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0118 - acc: 1.0000 - val_loss: 1.5355 - val_acc: 0.6172
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00035: val_acc did not improve from 0.63281
# Epoch 36/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0109 - acc: 1.0000 - val_loss: 1.5359 - val_acc: 0.6094
#
# Epoch 00036: val_acc did not improve from 0.63281
# Epoch 37/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0110 - acc: 1.0000 - val_loss: 1.5437 - val_acc: 0.6094
#
# Epoch 00037: val_acc did not improve from 0.63281
# Epoch 38/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0104 - acc: 1.0000 - val_loss: 1.5417 - val_acc: 0.6172
#
# Epoch 00038: val_acc did not improve from 0.63281
# Epoch 39/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0107 - acc: 1.0000 - val_loss: 1.5458 - val_acc: 0.6094
#
# Epoch 00039: val_acc did not improve from 0.63281
# Epoch 40/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0111 - acc: 1.0000 - val_loss: 1.5411 - val_acc: 0.6250
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00040: val_acc did not improve from 0.63281
# Epoch 41/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0100 - acc: 1.0000 - val_loss: 1.5411 - val_acc: 0.6250
#
# Epoch 00041: val_acc did not improve from 0.63281
# Epoch 42/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0105 - acc: 1.0000 - val_loss: 1.5468 - val_acc: 0.6250
#
# Epoch 00042: val_acc did not improve from 0.63281
# Epoch 43/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 1.5496 - val_acc: 0.6172
#
# Epoch 00043: val_acc did not improve from 0.63281
# Epoch 44/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0110 - acc: 1.0000 - val_loss: 1.5528 - val_acc: 0.6250
#
# Epoch 00044: val_acc did not improve from 0.63281
# Epoch 45/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0104 - acc: 1.0000 - val_loss: 1.5533 - val_acc: 0.6094
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00045: val_acc did not improve from 0.63281
# Epoch 46/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 1.5569 - val_acc: 0.6172
#
# Epoch 00046: val_acc did not improve from 0.63281
# Epoch 47/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0093 - acc: 1.0000 - val_loss: 1.5580 - val_acc: 0.6172
#
# Epoch 00047: val_acc did not improve from 0.63281
# Epoch 48/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 1.5535 - val_acc: 0.6172
#
# Epoch 00048: val_acc did not improve from 0.63281
# Epoch 49/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0101 - acc: 1.0000 - val_loss: 1.5558 - val_acc: 0.6172
#
# Epoch 00049: val_acc did not improve from 0.63281
# Epoch 50/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0098 - acc: 1.0000 - val_loss: 1.5567 - val_acc: 0.6172
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00050: val_acc did not improve from 0.63281
# Epoch 51/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0098 - acc: 1.0000 - val_loss: 1.5556 - val_acc: 0.6172
#
# Epoch 00051: val_acc did not improve from 0.63281
# Epoch 52/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0114 - acc: 1.0000 - val_loss: 1.5584 - val_acc: 0.6094
#
# Epoch 00052: val_acc did not improve from 0.63281
# Epoch 53/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 1.5563 - val_acc: 0.6172
#
# Epoch 00053: val_acc did not improve from 0.63281
# Epoch 54/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 1.5569 - val_acc: 0.6250
#
# Epoch 00054: val_acc did not improve from 0.63281
# Epoch 55/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0097 - acc: 1.0000 - val_loss: 1.5558 - val_acc: 0.6172
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00055: val_acc did not improve from 0.63281
# Epoch 56/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 1.5588 - val_acc: 0.6250
#
# Epoch 00056: val_acc did not improve from 0.63281
# Epoch 57/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0098 - acc: 1.0000 - val_loss: 1.5571 - val_acc: 0.6172
#
# Epoch 00057: val_acc did not improve from 0.63281
# Epoch 58/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 1.5575 - val_acc: 0.6250
#
# Epoch 00058: val_acc did not improve from 0.63281
# Epoch 59/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 1.5559 - val_acc: 0.6172
#
# Epoch 00059: val_acc did not improve from 0.63281
# Epoch 60/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 1.5563 - val_acc: 0.6172
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 00060: val_acc did not improve from 0.63281
# Epoch 61/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 1.5590 - val_acc: 0.6172
#
# Epoch 00061: val_acc did not improve from 0.63281
# Epoch 62/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0120 - acc: 1.0000 - val_loss: 1.5597 - val_acc: 0.6172
#
# Epoch 00062: val_acc did not improve from 0.63281
# Epoch 63/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 1.5622 - val_acc: 0.6094
#
# Epoch 00063: val_acc did not improve from 0.63281
# Epoch 64/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 1.5594 - val_acc: 0.6172
#
# Epoch 00064: val_acc did not improve from 0.63281
# Epoch 65/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 1.5607 - val_acc: 0.6172
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 00065: val_acc did not improve from 0.63281
# Epoch 66/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0083 - acc: 1.0000 - val_loss: 1.5611 - val_acc: 0.6172
#
# Epoch 00066: val_acc did not improve from 0.63281
# Epoch 67/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0087 - acc: 1.0000 - val_loss: 1.5626 - val_acc: 0.6094
#
# Epoch 00067: val_acc did not improve from 0.63281
# Epoch 68/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0093 - acc: 1.0000 - val_loss: 1.5613 - val_acc: 0.6172
#
# Epoch 00068: val_acc did not improve from 0.63281
# Epoch 69/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0093 - acc: 1.0000 - val_loss: 1.5615 - val_acc: 0.6172
#
# Epoch 00069: val_acc did not improve from 0.63281
# Epoch 70/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0125 - acc: 1.0000 - val_loss: 1.5625 - val_acc: 0.6094
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 00070: val_acc did not improve from 0.63281
# Epoch 71/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0097 - acc: 1.0000 - val_loss: 1.5605 - val_acc: 0.6172
#
# Epoch 00071: val_acc did not improve from 0.63281
# Epoch 72/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0085 - acc: 1.0000 - val_loss: 1.5606 - val_acc: 0.6172
#
# Epoch 00072: val_acc did not improve from 0.63281
# Epoch 73/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0101 - acc: 1.0000 - val_loss: 1.5613 - val_acc: 0.6172
#
# Epoch 00073: val_acc did not improve from 0.63281
# Epoch 74/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0109 - acc: 1.0000 - val_loss: 1.5612 - val_acc: 0.6172
#
# Epoch 00074: val_acc did not improve from 0.63281
# Epoch 75/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0107 - acc: 1.0000 - val_loss: 1.5620 - val_acc: 0.6172
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 00075: val_acc did not improve from 0.63281
# Epoch 76/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0085 - acc: 1.0000 - val_loss: 1.5602 - val_acc: 0.6172
#
# Epoch 00076: val_acc did not improve from 0.63281
# Epoch 77/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0100 - acc: 1.0000 - val_loss: 1.5624 - val_acc: 0.6094
#
# Epoch 00077: val_acc did not improve from 0.63281
# Epoch 78/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0097 - acc: 1.0000 - val_loss: 1.5591 - val_acc: 0.6172
#
# Epoch 00078: val_acc did not improve from 0.63281
# Epoch 79/100
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0100 - acc: 1.0000 - val_loss: 1.5633 - val_acc: 0.6172
#
# Epoch 00079: val_acc did not improve from 0.63281
# Epoch 80/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0101 - acc: 1.0000 - val_loss: 1.5590 - val_acc: 0.6172
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
#
# Epoch 00080: val_acc did not improve from 0.63281
# Epoch 81/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 1.5604 - val_acc: 0.6172
#
# Epoch 00081: val_acc did not improve from 0.63281
# Epoch 82/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 1.5612 - val_acc: 0.6172
#
# Epoch 00082: val_acc did not improve from 0.63281
# Epoch 83/100
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 1.5593 - val_acc: 0.6172
#
# Epoch 00083: val_acc did not improve from 0.63281
# Epoch 84/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 1.5589 - val_acc: 0.6172
#
# Epoch 00084: val_acc did not improve from 0.63281
# Epoch 85/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0104 - acc: 1.0000 - val_loss: 1.5584 - val_acc: 0.6172
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
#
# Epoch 00085: val_acc did not improve from 0.63281
# Epoch 86/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0101 - acc: 1.0000 - val_loss: 1.5638 - val_acc: 0.6172
#
# Epoch 00086: val_acc did not improve from 0.63281
# Epoch 87/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 1.5614 - val_acc: 0.6172
#
# Epoch 00087: val_acc did not improve from 0.63281
# Epoch 88/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0101 - acc: 1.0000 - val_loss: 1.5626 - val_acc: 0.6172
#
# Epoch 00088: val_acc did not improve from 0.63281
# Epoch 89/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0087 - acc: 1.0000 - val_loss: 1.5580 - val_acc: 0.6172
#
# Epoch 00089: val_acc did not improve from 0.63281
# Epoch 90/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 1.5571 - val_acc: 0.6172
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
#
# Epoch 00090: val_acc did not improve from 0.63281
# Epoch 91/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0094 - acc: 1.0000 - val_loss: 1.5588 - val_acc: 0.6172
#
# Epoch 00091: val_acc did not improve from 0.63281
# Epoch 92/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0087 - acc: 1.0000 - val_loss: 1.5647 - val_acc: 0.6172
#
# Epoch 00092: val_acc did not improve from 0.63281
# Epoch 93/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0093 - acc: 1.0000 - val_loss: 1.5642 - val_acc: 0.6172
#
# Epoch 00093: val_acc did not improve from 0.63281
# Epoch 94/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0110 - acc: 1.0000 - val_loss: 1.5607 - val_acc: 0.6172
#
# Epoch 00094: val_acc did not improve from 0.63281
# Epoch 95/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0085 - acc: 1.0000 - val_loss: 1.5605 - val_acc: 0.6172
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
#
# Epoch 00095: val_acc did not improve from 0.63281
# Epoch 96/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0098 - acc: 1.0000 - val_loss: 1.5608 - val_acc: 0.6172
#
# Epoch 00096: val_acc did not improve from 0.63281
# Epoch 97/100
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 1.5610 - val_acc: 0.6172
#
# Epoch 00097: val_acc did not improve from 0.63281
# Epoch 98/100
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0098 - acc: 1.0000 - val_loss: 1.5616 - val_acc: 0.6172
#
# Epoch 00098: val_acc did not improve from 0.63281
# Epoch 99/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 1.5608 - val_acc: 0.6172
#
# Epoch 00099: val_acc did not improve from 0.63281
# Epoch 100/100
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 1.5619 - val_acc: 0.6094
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
#
# Epoch 00100: val_acc did not improve from 0.63281

# %% [markdown]
# #Results and Plots

# %%
model_speech.load_weights('/content/drive/MyDrive/8th sem/audio_project/checkpoint_weights.h5')
#model.save('')

plt.plot(history.history['loss'] , label = 'train_loss')
plt.plot(history.history['val_loss'] , label = 'val_loss')
plt.legend()
plt.xlabel("No. of epochs")
plt.ylabel("Loss(Categorical Crossentropy)")
plt.title("Loss vs. Epoch plot for BRNN+weighted_mean_pooling")
plt.show()

plt.plot(history.history['acc'] , label = 'train_acc')
plt.plot(history.history['val_acc'] , label = 'val_acc')
plt.legend()
plt.xlabel("No. of epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy vs. Epoch plot for BRNN+weighted_mean_pooling")
plt.show()



#print('original')
orig = np.argmax(test_y,axis=1) 
#print(orig)
#print('\n')
#print('predicted')
pred = model_speech.predict_generator(test_x , steps = 32 , verbose = 0)
pred_class_indices = np.argmax(pred,axis=1)
#print(pred_class_indices)
#print('\n')


print('\n')
from sklearn.metrics import precision_score,recall_score,accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score,jaccard_score,classification_report
print('Precision {}'.format(precision_score(y_true=orig, y_pred=pred_class_indices,average = 'macro')))
print('Recall {}'.format(recall_score(y_true=orig, y_pred=pred_class_indices,average='macro')))
print('Accuracy {}'.format(accuracy_score(y_true=orig, y_pred=pred_class_indices)))
print('F1 {}'.format(f1_score(y_true=orig, y_pred=pred_class_indices,average = 'macro')))
print('jaccard {}'.format(jaccard_score(y_true=orig, y_pred=pred_class_indices,average = 'macro')))
#print('confusion_matrix\n {}'.format(confusion_matrix(y_true=orig, y_pred=pred_class_indices)))
#print('classification_report\n {}'.format(classification_report(y_true=orig, y_pred=pred_class_indices)))
print('\n\n')


met = np.zeros((9,5))

avg_met = [precision_score(y_true=orig, y_pred=pred_class_indices,average = 'macro'),
           recall_score(y_true=orig, y_pred=pred_class_indices,average='macro'),
           f1_score(y_true=orig, y_pred=pred_class_indices,average = 'macro'),
           jaccard_score(y_true=orig, y_pred=pred_class_indices,average = 'macro'),
           accuracy_score(y_true=orig, y_pred=pred_class_indices)]

avg_met = np.array(avg_met)
avg_met.round(decimals=2)
met[8,:] = avg_met

#print(met)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
#
#
# Precision 0.6733435448959643
# Recall 0.6596366995073891
# Accuracy 0.6759259259259259
# F1 0.6608015335363678
# jaccard 0.5063883344793672

# %% [markdown]
# #Class Wise Results

# %%
classes = [0,1,2,3,4,5,6,7]


for cl in classes:

    print("class: ",EMOTIONS[cl])

    a1 = np.uint8(orig == cl)
    a2 = np.uint8(pred_class_indices == cl)

    print('Accuracy {}'.format(accuracy_score(y_true=a1, y_pred=a2)))
    print('F1 {}'.format(f1_score(y_true=a1, y_pred=a2)))
    print('precision {}'.format(precision_score(y_true=a1, y_pred=a2)))
    print('recall {}'.format(recall_score(y_true=a1, y_pred=a2)))

    print('jaccard {}'.format(jaccard_score(y_true=a1, y_pred=a2)))
    print("_______________________________")


    class_met = [precision_score(y_true=a1, y_pred=a2),
                 recall_score(y_true=a1, y_pred=a2),
                 f1_score(y_true=a1, y_pred=a2),
                 jaccard_score(y_true=a1, y_pred=a2),
                 accuracy_score(y_true=a1, y_pred=a2)]

    class_met = np.array(class_met)
    class_met.round(decimals=2)
    met[cl,:] =class_met
# Out:
# class:  Neutral
# Accuracy 0.9212962962962963
# F1 0.4137931034482759
# precision 0.4
# recall 0.42857142857142855
# jaccard 0.2608695652173913
# _______________________________
# class:  Calm
# Accuracy 0.9166666666666666
# F1 0.6538461538461539
# precision 0.7083333333333334
# recall 0.6071428571428571
# jaccard 0.4857142857142857
# _______________________________
# class:  Happy
# Accuracy 0.9074074074074074
# F1 0.6875
# precision 0.6285714285714286
# recall 0.7586206896551724
# jaccard 0.5238095238095238
# _______________________________
# class:  Sad
# Accuracy 0.8611111111111112
# F1 0.5161290322580646
# precision 0.48484848484848486
# recall 0.5517241379310345
# jaccard 0.34782608695652173
# _______________________________
# class:  Angry
# Accuracy 0.9166666666666666
# F1 0.7
# precision 0.6774193548387096
# recall 0.7241379310344828
# jaccard 0.5384615384615384
# _______________________________
# class:  Fearful
# Accuracy 0.9444444444444444
# F1 0.8064516129032258
# precision 0.7575757575757576
# recall 0.8620689655172413
# jaccard 0.6756756756756757
# _______________________________
# class:  Disgust
# Accuracy 0.9537037037037037
# F1 0.8148148148148148
# precision 0.88
# recall 0.7586206896551724
# jaccard 0.6875
# _______________________________
# class:  Surprised
# Accuracy 0.9305555555555556
# F1 0.6938775510204082
# precision 0.85
# recall 0.5862068965517241
# jaccard 0.53125
# _______________________________

# %% [markdown]
# #Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
cm = confusion_matrix(y_true=orig, y_pred=pred_class_indices)
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    # if normalize:
    #     cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    #     print("Normalized confusion matrix")
    # else:
    #     print('Confusion matrix, without normalization')

    # print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(cm, EMOTIONS,
                        normalize=False,
                        title='Confusion matrix for BRNN+weighted_mean_pooling',
                        cmap=plt.cm.Blues)
